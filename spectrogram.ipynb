# %%
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt

f_name = 'lluviasuave.wav'
#path = # path where to save result

X, s_rate = librosa.load(f_name, res_type='kaiser_fast', duration=4.0)

mfc = librosa.feature.melspectrogram(y=X, sr=s_rate)
ch = librosa.feature.chroma_stft(y=X, sr=s_rate)
sc = librosa.feature.spectral_contrast(y=X, sr=s_rate)
tz = librosa.feature.tonnetz(y=X, sr=s_rate)

small_MFCC = np.concatenate([mfc, ch, sc, tz], axis=0)
librosa.display.specshow(small_MFCC)
# Out:
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py in load(path, sr, mono, offset, duration, dtype, res_type)
#     148     try:
# --> 149         with sf.SoundFile(path) as sf_desc:
#     150             sr_native = sf_desc.samplerate
#
# /usr/local/lib/python3.7/dist-packages/soundfile.py in __init__(self, file, mode, samplerate, channels, subtype, endian, format, closefd)
#     628                                          format, subtype, endian)
# --> 629         self._file = self._open(file, mode_int, closefd)
#     630         if set(mode).issuperset('r+') and self.seekable():
#
# ...

# %%
plt.plot(mfc)

# %%
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt

f_name = 'lluviasuave.wav'
y, sr = librosa.load(f_name, duration=15)

D = librosa.amplitude_to_db(np.abs(librosa.stft(y)), ref=np.max)
img = librosa.display.specshow(D, y_axis='linear', x_axis='time',
                               sr=sr, ax=ax[0])

# %%
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt

f_name = 'lluvia.wav'
y, sr = librosa.load(f_name, duration=15)
fig, ax = plt.subplots(nrows=2, ncols=1, sharex=True)
D = librosa.amplitude_to_db(np.abs(librosa.stft(y)), ref=np.max)
img = librosa.display.specshow(D, y_axis='linear', x_axis='time',
                               sr=sr, ax=ax[0])

# %%
sr
# Out:
# 22050

# %%
y
# Out:
# array([0.00720618, 0.02396249, 0.01662864, ..., 0.03439829, 0.02208885,
#        0.02497914], dtype=float32)

# %%
y, sr = librosa.load(f_name, duration=20)
D = librosa.amplitude_to_db(np.abs(librosa.stft(y)), ref=np.max)
D.shape
# Out:
# (1025, 862)

# %%
f_name = 'lluvia.wav'
y, sr = librosa.load(f_name, duration=10)
stf=librosa.stft(y)
plt.plot(stf.mean(axis=1))
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
f_name = 'lluviasuave.wav'
y, sr = librosa.load(f_name, duration=50)
D = librosa.amplitude_to_db(np.abs(librosa.stft(y)), ref=np.max)
plt.plot(D.mean(axis=1))
plt.xticks(xi, x)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-115-7e6efcf741b9> in <module>()
#       3 D = librosa.amplitude_to_db(np.abs(librosa.stft(y)), ref=np.max)
#       4 plt.plot(D.mean(axis=1))
# ----> 5 plt.xticks(xi, x)
#       6 plt.show()
#
# NameError: name 'xi' is not defined

# %%
stf=np.abs(librosa.stft(y))

# %%
stf.mean(axis=1)
# Out:
# array([2.4784933e+01, 1.2392542e+01, 8.0013141e-02, ..., 8.2759754e-05,
#        7.7249271e-05, 6.9066780e-05], dtype=float32)

# %%
plt.plot(stf.mean(axis=1))

plt.show()

# %%
plt.plot(stf.mean(axis=1))
x_ticks_positions = [n for n in range(0, n_fft // 2, n_fft // 16)]
x_ticks_labels = [str(sr / 2048 * n) + 'Hz' for n in x_ticks_positions]
plt.xticks(x_ticks_positions, x_ticks_labels)
plt.xlabel('Frequency')
plt.ylabel('dB')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
np.max
# Out:
# <function numpy.amax>

# %%
f_name = 'lluvia.wav'
y, sr = librosa.load(f_name, duration=50)
D = librosa.amplitude_to_db(np.abs(librosa.stft(y)), ref=np.max)
plt.plot(D.mean(axis=1))
plt.show()

# %%
import os
import wave

import pylab
def graph_spectrogram(wav_file):
    sound_info, frame_rate = get_wav_info(wav_file)
    pylab.figure(num=None, figsize=(19, 12))
    pylab.subplot(111)
    pylab.title('spectrogram of %r' % wav_file)
    pylab.specgram(sound_info, Fs=frame_rate)
    pylab.savefig('spectrogram.png')
def get_wav_info(wav_file):
    wav = wave.open(wav_file, 'r')
    frames = wav.readframes(-1)
    sound_info = pylab.fromstring(frames, 'int16')
    frame_rate = wav.getframerate()
    wav.close()
    return sound_info, frame_rate

# %%
wav_file='lluvia.wav'
sound_info, frame_rate = get_wav_info(wav_file)
pylab.figure(num=None, figsize=(19, 12))
pylab.subplot(111)
pylab.title('spectrogram of %r' % wav_file)
pylab.specgram(sound_info, Fs=frame_rate)
pylab.savefig('spectrogram.png')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   from ipykernel import kernelapp as app

# %%
s,f,t,im=pylab.specgram(sound_info, Fs=frame_rate)

# %%
s
# Out:
# (129, 41343)

# %%
sr
# Out:
# 22050

# %%
# Out:
# /content/drive/MyDrive/Doctorado/Junio

# %%
import librosa
import numpy as np
import matplotlib.pyplot as plt

from matplotlib.pyplot import figure

figure(figsize=(15, 15), dpi=80)

file = 'lluviasuave.wav'
# load the file
y, sr = librosa.load(file, sr=44100)
# short time fourier transform
# (n_fft and hop length determine frequency/time resolution)
n_fft = 1024
S = librosa.stft(y)
# convert to db
# (for your CNN you might want to skip this and rather ensure zero mean and unit variance)
D = librosa.amplitude_to_db(np.abs(S), ref=np.max)
# average over file
D_AVG = np.mean(S, axis=1)

# %%
plt.plot(D_AVG)
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
S.shape
# Out:
# (513, 5169)

# %%
x_ticks_positions
# Out:
# [0, 64, 128, 192, 256, 320, 384, 448]

# %%
x_ticks_labels
# Out:
# ['0.0Hz',
#  '1378.125Hz',
#  '2756.25Hz',
#  '4134.375Hz',
#  '5512.5Hz',
#  '6890.625Hz',
#  '8268.75Hz',
#  '9646.875Hz']

# %%
plt.plot(np.arange(D_AVG[:255].shape[0]), D_AVG[:255])
x_ticks_positions = [n for n in range(0, n_fft // 2, n_fft // 16)]
x_ticks_labels = [str(sr / 2048 * n) + 'Hz' for n in x_ticks_positions]
plt.xticks(x_ticks_positions[:4], x_ticks_labels[:4])
plt.xlabel('Frequency')
plt.ylabel('dB')
plt.show()

# %%
import librosa
import numpy as np
import matplotlib.pyplot as plt

from matplotlib.pyplot import figure

figure(figsize=(15, 15), dpi=80)

file = 'lluvia.wav'
# load the file
y, sr = librosa.load(file, sr=44100)
# short time fourier transform
# (n_fft and hop length determine frequency/time resolution)
n_fft = 1024
S = librosa.stft(y, n_fft=n_fft, hop_length=n_fft//2)
# convert to db
# (for your CNN you might want to skip this and rather ensure zero mean and unit variance)
D = librosa.amplitude_to_db(np.abs(S), ref=np.max)
# average over file
D_AVG = np.mean(D, axis=1)

plt.plot(np.arange(D_AVG.shape[0]), D_AVG)
x_ticks_positions = [n for n in range(0, n_fft // 2, n_fft // 16)]
x_ticks_labels = [str(sr / 2048 * n) + 'Hz' for n in x_ticks_positions]
plt.xticks(x_ticks_positions, x_ticks_labels)
plt.xlabel('Frequency')
plt.ylabel('dB')
plt.show()

# %%
figure(figsize=(15, 15), dpi=80)

f_name = '/content/drive/MyDrive/Doctorado/Junio/lluvia.wav'
y, sr = librosa.load(f_name, duration=50)
D = librosa.amplitude_to_db(np.abs(librosa.stft(y)), ref=np.max)
plt.plot(D.mean(axis=1))
x_ticks_positions = [n for n in range(0, n_fft // 2, n_fft // 16)]
x_ticks_labels = [str(sr / 2048 * n) + 'Hz' for n in x_ticks_positions]
plt.xticks(x_ticks_positions, x_ticks_labels)
plt.xlabel('Frequency')
plt.ylabel('dB')
plt.show()

# %%
import librosa
import numpy as np
import matplotlib.pyplot as plt

from matplotlib.pyplot import figure

figure(figsize=(15, 15), dpi=80)

file = '/content/drive/MyDrive/Doctorado/Junio/lluviasuave.wav'
# load the file
y, sr = librosa.load(file, sr=44100)
# short time fourier transform
# (n_fft and hop length determine frequency/time resolution)
n_fft = 1024
S = librosa.stft(y, n_fft=n_fft, hop_length=n_fft//2)
# convert to db
# (for your CNN you might want to skip this and rather ensure zero mean and unit variance)
D = librosa.amplitude_to_db(np.abs(S), ref=np.max)
# average over file
D_AVG = np.mean(D, axis=1)

# %%
D = librosa.amplitude_to_db(np.abs(S), ref=np.max)
# average over file
D_AVG = np.mean(S, axis=1)

# %%
D[:100]
# Out:
# array([[ -0.3451538 ,  -0.27720642,  -0.2263813 , ...,  -0.20736694,
#          -0.13036346,  -0.25680923],
#        [ -6.3912773 ,  -6.2962475 ,  -6.2371864 , ...,  -6.2288475 ,
#          -6.1531982 ,  -6.2463646 ],
#        [-49.35856   , -47.082573  , -44.605854  , ..., -41.09566   ,
#         -43.926105  , -42.3515    ],
#        ...,
#        [-59.63572   , -80.        , -80.        , ..., -80.        ,
#         -80.        , -80.        ],
#        [-59.63656   , -80.        , -80.        , ..., -80.        ,
#         -80.        , -80.        ],
#        [-59.641754  , -80.        , -80.        , ..., -80.        ,
#         -80.        , -80.        ]], dtype=float32)

# %%
plt.plot(np.arange(D_AVG.shape[0]), D_AVG)
x_ticks_positions = [n for n in range(0, n_fft // 2, n_fft // 16)]
x_ticks_labels = [str(sr / 2048 * n) + 'Hz' for n in x_ticks_positions]
plt.xticks(x_ticks_positions, x_ticks_labels)
plt.xlabel('Frequency')
plt.ylabel('dB')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %% [markdown]
# # 90% signal

# %%
import librosa
import numpy as np
import matplotlib.pyplot as plt

from matplotlib.pyplot import figure

figure(figsize=(15, 15), dpi=80)

file = '/content/drive/MyDrive/Doctorado/Junio/LLuvia/lluvia.wav'
# load the file
y, sr = librosa.load(file, sr=44100)
# short time fourier transform
# (n_fft and hop length determine frequency/time resolution)
n_fft = 1024
S = librosa.stft(y, n_fft=n_fft, hop_length=n_fft//2)
# convert to db
# (for your CNN you might want to skip this and rather ensure zero mean and unit variance)
D = librosa.amplitude_to_db(np.abs(S), ref=np.max)
# average over file
D_AVG = np.mean(D, axis=1)

plt.plot(np.arange(D_AVG.shape[0]), D_AVG)
x_ticks_positions = [n for n in range(0, n_fft // 2, n_fft // 16)]
x_ticks_labels = [str(sr / 2048 * n) + 'Hz' for n in x_ticks_positions]
plt.xticks(x_ticks_positions, x_ticks_labels)
plt.xlabel('Frequency')
plt.ylabel('dB')
plt.show()

# %%
import librosa
import numpy as np
import matplotlib.pyplot as plt

from matplotlib.pyplot import figure

figure(figsize=(15, 15), dpi=80)

file = '/content/drive/MyDrive/Doctorado/Junio/LLuvia/fuerte2.wav'
# load the file
y, sr = librosa.load(file, sr=44100)
# short time fourier transform
# (n_fft and hop length determine frequency/time resolution)
n_fft = 1024
S = librosa.stft(y, n_fft=n_fft, hop_length=n_fft//2)
# convert to db
# (for your CNN you might want to skip this and rather ensure zero mean and unit variance)
D = librosa.amplitude_to_db(np.abs(S), ref=np.max)
# average over file
D_AVG = np.mean(D, axis=1)

plt.plot(np.arange(D_AVG.shape[0]), D_AVG)

x_ticks_positions = [n for n in range(0, n_fft // 2, n_fft // 16)]
x_ticks_labels = [str(sr / 2048 * n) + 'Hz' for n in x_ticks_positions]
plt.xticks(x_ticks_positions, x_ticks_labels)
plt.xlabel('Frequency')
plt.ylabel('dB')
plt.show()

# %%
D_AVG.shape
# Out:
# (513,)

# %%
import librosa
import numpy as np
import matplotlib.pyplot as plt

from matplotlib.pyplot import figure

figure(figsize=(15, 15), dpi=80)

file = '/content/drive/MyDrive/Doctorado/Junio/LLuvia/fuerte2.wav'
# load the file
y, sr = librosa.load(file, sr=44100)
# short time fourier transform
# (n_fft and hop length determine frequency/time resolution)
n_fft = 1024
S = librosa.stft(y, n_fft=n_fft, hop_length=n_fft//2)
# convert to db
# (for your CNN you might want to skip this and rather ensure zero mean and unit variance)
D = librosa.amplitude_to_db(np.abs(S), ref=np.max)
# average over file
D_AVG = np.mean(D, axis=1)

plt.plot(np.arange(D_AVG.shape[0]), D_AVG)

x_ticks_positions = [n for n in range(0, n_fft // 2, n_fft // 16)]
x_ticks_labels = [str(sr / 2048 * n) + 'Hz' for n in x_ticks_positions]
plt.xticks(x_ticks_positions, x_ticks_labels)
plt.xlabel('Frequency')
plt.ylabel('dB')
plt.show()

# %% [markdown]
# # Sección nueva

# %%
s=D.sum(axis=0)

# %%
cp=s.cumsum()

# %%
plt.plot(cp/cp[-1])

# %%
cp=np.cumsum(s)

# %%
plt.plot(cp)
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %% [markdown]
# # Grafica de varios espectrogramas

# %%
ls /content/drive/MyDrive/Doctorado/Junio/LLuvia/
# Out:
# 'Conectividad y distance.gslides'   meanfrquencyvsdb.png
#  fuerte2.wav                        meanfrquencyvsdb.svg
#  fuerte.wav                         media.wav
#  lluviasuave.wav                    muysuave.wav
#  lluvia.wav                         sample-graph.png
#  meanfrquencyvsdbaumenteg.png       spectrogram.ipynb
#  meanfrquencyvsdbaumenteg.svg       spectrogram.png

# %%
import librosa
import numpy as np
import matplotlib.pyplot as plt

from matplotlib.pyplot import figure

figure(figsize=(15, 15), dpi=80)

file = '/content/drive/MyDrive/Doctorado/Junio/LLuvia/lluviasuave.wav'
# load the file
y, sr = librosa.load(file, sr=44100)
# short time fourier transform
# (n_fft and hop length determine frequency/time resolution)
n_fft = 1024
S = librosa.stft(y, n_fft=n_fft, hop_length=n_fft//2)
# convert to db
# (for your CNN you might want to skip this and rather ensure zero mean and unit variance)
D = librosa.amplitude_to_db(np.abs(S), ref=np.max)
# average over file
D_AVG = np.mean(D, axis=1)

plt.plot(np.arange(D_AVG.shape[0]), D_AVG)

x_ticks_positions = [n for n in range(0, n_fft // 2, n_fft // 16)]
x_ticks_labels = [str(sr / 2048 * n) + 'Hz' for n in x_ticks_positions]
plt.xticks(x_ticks_positions, x_ticks_labels)
plt.xlabel('Frequency')
plt.ylabel('dB')
plt.show()

# %%
import librosa
import numpy as np
import matplotlib.pyplot as plt

from matplotlib.pyplot import figure
from matplotlib import style

style.use('ggplot') or plt.style.use('ggplot')


figure(figsize=(15, 7), dpi=80)

file = 'muysuave.wav'
# load the file
y, sr = librosa.load(file, sr=44100)
# short time fourier transform
# (n_fft and hop length determine frequency/time resolution)
n_fft = 1024
S = librosa.stft(y, n_fft=n_fft, hop_length=n_fft//2)
# convert to db
# (for your CNN you might want to skip this and rather ensure zero mean and unit variance)
D = librosa.amplitude_to_db(np.abs(S), ref=np.max)
# average over file
D_AVGmuysuave = np.mean(D, axis=1)

plt.plot(np.arange(D_AVGmuysuave.shape[0]), D_AVGmuysuave,label='light rain', linewidth =4)

file = 'lluvia.wav'
# load the file
y, sr = librosa.load(file, sr=44100)
# short time fourier transform
# (n_fft and hop length determine frequency/time resolution)
n_fft = 1024
S = librosa.stft(y, n_fft=n_fft, hop_length=n_fft//2)
# convert to db
# (for your CNN you might want to skip this and rather ensure zero mean and unit variance)
D = librosa.amplitude_to_db(np.abs(S), ref=np.max)
# average over file
D_AVGlluvia = np.mean(D, axis=1)

plt.plot(np.arange(D_AVGlluvia.shape[0]), D_AVGlluvia,label='moderate rain', linewidth =4)

file = 'fuerte.wav'
# load the file
y, sr = librosa.load(file, sr=44100)
# short time fourier transform
# (n_fft and hop length determine frequency/time resolution)
n_fft = 1024
S = librosa.stft(y, n_fft=n_fft, hop_length=n_fft//2)
# convert to db
# (for your CNN you might want to skip this and rather ensure zero mean and unit variance)
D = librosa.amplitude_to_db(np.abs(S), ref=np.max)
# average over file
D_AVGfuerte = np.mean(D, axis=1)

plt.plot(np.arange(D_AVGfuerte.shape[0]), D_AVGfuerte,label='violent', linewidth =4)



file = 'fuerte2.wav'
# load the file
y, sr = librosa.load(file, sr=44100)
# short time fourier transform
# (n_fft and hop length determine frequency/time resolution)
n_fft = 1024
S = librosa.stft(y, n_fft=n_fft, hop_length=n_fft//2)
# convert to db
# (for your CNN you might want to skip this and rather ensure zero mean and unit variance)
D = librosa.amplitude_to_db(np.abs(S), ref=np.max)
# average over file
D_AVGlluviamuy = np.mean(D, axis=1)

plt.plot(np.arange(D_AVGlluviamuy.shape[0]), D_AVGlluviamuy,label='heavy', linewidth =4)

x_ticks_positions = [n for n in range(0, n_fft // 2, n_fft // 16)]
x_ticks_labels = [str(sr / 2048 * n)  for n in x_ticks_positions]
plt.xticks(x_ticks_positions, x_ticks_labels,  fontsize=18)
plt.yticks(fontsize=25)
plt.legend(fontsize=25)
plt.xlabel('Frequency (Hz)', fontsize=30)
plt.ylabel('dB', fontsize=30)
#plt.savefig('variostiposdelluvia.svg', format='svg', dpi=1200)
plt.show()

# %%
pwd
# Out:
# '/content'
